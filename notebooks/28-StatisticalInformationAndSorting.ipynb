# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(filepath_or_buffer='./datasets/tips.csv')

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df['tip'].sort_values()
# Out:
# 67      1.00
# 236     1.00
# 92      1.00
# 111     1.00
# 0       1.01
#        ...
# 141     6.70
# 59      6.73
# 23      7.58
# 212     9.00
# 170    10.00
# Name: tip, Length: 244, dtype: float64

# %%
df.sort_values(by='tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values(by=['tip', 'size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# sort in descending order
df.sort_values(by=['tip', 'size'], ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# to get the max value of tip
df['tip'].max()
# Out:
# np.float64(10.0)

# %%
# to get the index location of max value
df['tip'].idxmax()
# Out:
# 170

# %%
# we can use this to get the row
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.iloc[23]
# Out:
# total_bill                     39.42
# tip                             7.58
# sex                             Male
# smoker                            No
# day                              Sat
# time                          Dinner
# size                               4
# price_per_person                9.86
# Payer Name            Lance Peterson
# CC Number           3542584061609808
# Payment ID                    Sat239
# Name: 23, dtype: object

# %%
df.iloc[df['tip'].idxmax()]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.sample(4)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 208       24.27  2.03    Male    Yes   Sat  Dinner     2             12.14
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 118       12.43  1.80  Female     No  Thur   Lunch     2              6.22
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2              5.30
#
#               Payer Name         CC Number Payment ID
# 208         Jason Carter  4268942915626180    Sat6048
# 14         Vanessa Jones    30016702287574    Sun3848
# 118  Dr. Caroline Tucker      502047186908   Thur8084
# 168         Sara Jimenez      502053147208    Sat9795

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.corr()
#
# File ~/Desktop/Programming/Python/data-science/udemy/pierian-ml/venv/lib/python3.11/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Desktop/Programming/Python/data-science/udemy/pierian-ml/venv/lib/python3.11/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
# since pandas version 2.0.0 now you need to add numeric_only=True param to avoid the issue
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
# for categorical columns
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
# to get unique values
df['sex'].nunique()
# Out:
# 2

# %%
df['day'].nunique()
# Out:
# 4

# %%
# to get unique values
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
# replace the specific value in dataframe
df_copy = df.copy()

# %%
df_copy['sex'] = df_copy['sex'].replace('Female', 'F')

# %%
df_copy.sample(6)
# Out:
#      total_bill   tip   sex smoker   day    time  size  price_per_person  \
# 8         15.04  1.96  Male     No   Sun  Dinner     2              7.52
# 90        28.97  3.00  Male    Yes   Fri  Dinner     2             14.48
# 148        9.78  1.73  Male     No  Thur   Lunch     2              4.89
# 214       28.17  6.50     F    Yes   Sat  Dinner     3              9.39
# 29        19.65  3.00     F     No   Sat  Dinner     2              9.82
# 43         9.68  1.32  Male     No   Sun  Dinner     2              4.84
#
#              Payer Name         CC Number Payment ID
# 8       Joseph Mcdonald  3522866365840377    Sun6820
# 90         Daniel Mason  3597456900644078    Fri4175
# 148       David Stewart  3578014604116399   Thur7276
# 214     Marissa Jackson  4922302538691962    Sat3374
# 29       Melinda Murphy  5489272944576051    Sat2467
# 43   Christopher Spears  4387671121369212    Sun3279

# %%
# we can also replace multiple values from same column
df_copy['sex'] = df_copy['sex'].replace(['Male', 'F'], ['M', 'Female'])

# %%
df_copy.sample(4)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 77        27.20  4.00       M     No  Thur   Lunch     4              6.80
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 9         14.78  3.23       M     No   Sun  Dinner     2              7.39
#
#          Payer Name         CC Number Payment ID
# 202     Ashley Shaw   180088043008041   Thur1301
# 77       John Davis    30344778738589   Thur4924
# 238  Kimberly Crane      676184013727    Sat9777
# 9     Jerome Abbott  3532124519049786    Sun3775

# %%
# to get the duplicate rows 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sum([True, False, True, True, False]) # True = 1 and hence 3
# Out:
# 3

# %%
dummy_df = pd.DataFrame({'name': ['Rama', 'Krishna', 'Rama'], 'age':[23,25,23]})

# %%
dummy_df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# to remove duplicate 
dummy_df.drop_duplicates()
# Out:
#       name  age
# 0     Rama   23
# 1  Krishna   25

# %%
df.isna().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
# creating df with null values
df_nan = pd.DataFrame([[1, 4, 5, np.nan, 8],[4,8,3,9,2]], columns=['idx1', 'idx2', 'idx3', 'idx4', 'idx5'])

# %%
df_nan
# Out:
#    idx1  idx2  idx3  idx4  idx5
# 0     1     4     5   NaN     8
# 1     4     8     3   9.0     2

# %%
df_nan.isna().sum()
# Out:
# idx1    0
# idx2    0
# idx3    0
# idx4    1
# idx5    0
# dtype: int64

# %%
# drop nan value # it drop the complete row having null/nan value in it
df_nan.dropna()
# Out:
#    idx1  idx2  idx3  idx4  idx5
# 1     4     8     3   9.0     2

# %%
# to get the values between 
df[df['total_bill'].between(10, 20)] # exclude 20
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# to include 20 
df[df['total_bill'].between(10, 20, inclusive='right')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# to get the n largest 
df.nlargest(n=4, columns='tip')
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No  Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139

# %%
# to get the n largest 
df.nlargest(n=4, columns=['size','price_per_person'])
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person  \
# 156       48.17  5.0    Male     No   Sun  Dinner     6              8.03
# 141       34.30  6.7    Male     No  Thur   Lunch     6              5.72
# 125       29.80  4.2  Female     No  Thur   Lunch     6              4.97
# 143       27.05  5.0  Female     No  Thur   Lunch     6              4.51
#
#          Payer Name         CC Number Payment ID
# 156   Ryan Gonzales  3523151482063321    Sun7518
# 141  Steven Carlson  3526515703718508   Thur1025
# 125  Angela Sanchez      503857080488   Thur3948
# 143    Regina Jones     4311048695487   Thur6179

# %%
# to get the n largest 
df.nsmallest(n=4, columns=['size','price_per_person'])
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1              8.58
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
#
#          Payer Name         CC Number Payment ID
# 67    Tiffany Brock  4359488526995267    Sat3455
# 111     Terri Jones  3559221007826887    Sat4801
# 222  Jason Lawrence  3505302934650403    Fri6624
# 82      Julie Moody      630413282843   Thur4909
